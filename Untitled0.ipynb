# %%
import numpy as np

  #create arrays
a = np.array([1,2,3,4])
b = np.array([[1,2],[3,4]])
#Array shape
print(a.shape)
print(b.shape)
#Basic operations
print(a*2)
print(a+2)
print(a+a)
# Out:
# (4,)
# (2, 2)
# [2 4 6 8]
# [3 4 5 6]
# [2 4 6 8]
